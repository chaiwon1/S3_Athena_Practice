# %%
import awswrangler as wr
from datetime import datetime
import pandas as pd

# %%
raw_s3_bucket = "dfncodetestbucket"
raw_path_dir = "original_data/attribution_data"
raw_path = f"s3://{raw_s3_bucket}/{raw_path_dir}"

standardized_s3_bucket = "dfncodetestbucket" 
standard_path_dir = "converted_data/attribution_data/"
standardized_path = f"s3://{standardized_s3_bucket}/{standard_path_dir}"

# %%
header = ['partner', 'campaign', 'server_datetime', 'tracker_id', 'log_id', 'attribution_type', 'identity_adid']

df = wr.s3.read_csv(raw_path, names=header)
df.head()
# Out:
#   partner campaign          server_datetime tracker_id  \
# 0     NaN      NaN  2018-05-03 07:19:24.813        NaN
# 1     NaN      NaN  2018-05-03 10:25:11.034        NaN
# 2     NaN      NaN  2018-05-03 10:26:08.081        NaN
# 3     NaN      NaN  2018-05-03 22:38:15.378        NaN
# 4     NaN      NaN  2018-05-03 04:14:55.453        NaN
#
#                                  log_id  attribution_type  identity_adid
# 0  bdb8fc95-4f66-4d1d-8186-d10e86fe6433                 0      764796223
# 1  67c41325-a700-4f98-ad72-108025e9af8d                 0     2126194985
# 2  0e41af66-3f17-4bde-91db-806296209ad1                 0      738518810
# 3  a5f7ed1f-5d4e-4adf-96ce-e94f6820c2c2                 0      595719449
# 4  1e1aae33-282d-4dc2-9267-22fbd4ee2798                 0      302402748

# %%
df = df.astype({"partner" : "str", 
                "campaign" : "str",
                "tracker_id" : "str",
                "log_id" : "str",
                "attribution_type" : "Int64",
                "identity_adid" : "str"
                })

# %%
df["server_datetime"] = pd.to_datetime(df["server_datetime"], errors = 'coerce')

# %%
df['server_datetime'] = df["server_datetime"].dt.strftime("%Y-%m-%d")

# %%
df.head()
# Out:
#   partner campaign server_datetime tracker_id  \
# 0     nan      nan      2018-05-03        nan
# 1     nan      nan      2018-05-03        nan
# 2     nan      nan      2018-05-03        nan
# 3     nan      nan      2018-05-03        nan
# 4     nan      nan      2018-05-03        nan
#
#                                  log_id  attribution_type identity_adid
# 0  bdb8fc95-4f66-4d1d-8186-d10e86fe6433                 0     764796223
# 1  67c41325-a700-4f98-ad72-108025e9af8d                 0    2126194985
# 2  0e41af66-3f17-4bde-91db-806296209ad1                 0     738518810
# 3  a5f7ed1f-5d4e-4adf-96ce-e94f6820c2c2                 0     595719449
# 4  1e1aae33-282d-4dc2-9267-22fbd4ee2798                 0     302402748

# %%
df.dtypes
# Out:
# partner             object
# campaign            object
# server_datetime     object
# tracker_id          object
# log_id              object
# attribution_type     Int64
# identity_adid       object
# dtype: object

# %%
partition = ['server_datetime']
wr.s3.to_parquet(df, path=standardized_path, dataset=True, partition_cols=partition)
# Out:
# {'paths': ['s3://dfncodetestbucket/converted_data/attribution_data/server_datetime=2018-05-02/ecb5306fc9f3434985beaea0a1926ba9.snappy.parquet',
#   's3://dfncodetestbucket/converted_data/attribution_data/server_datetime=2018-05-03/ecb5306fc9f3434985beaea0a1926ba9.snappy.parquet',
#   's3://dfncodetestbucket/converted_data/attribution_data/server_datetime=2018-05-04/ecb5306fc9f3434985beaea0a1926ba9.snappy.parquet',
#   's3://dfncodetestbucket/converted_data/attribution_data/server_datetime=2018-05-05/ecb5306fc9f3434985beaea0a1926ba9.snappy.parquet',
#   's3://dfncodetestbucket/converted_data/attribution_data/server_datetime=2018-05-06/ecb5306fc9f3434985beaea0a1926ba9.snappy.parquet',
#   's3://dfncodetestbucket/converted_data/attribution_data/server_datetime=2018-05-07/ecb5306fc9f3434985beaea0a1926ba9.snappy.parquet',
#   's3://dfncodetestbucket/converted_data/attribution_data/server_datetime=2018-05-08/ecb5306fc9f3434985beaea0a1926ba9.snappy.parquet',
#   's3://dfncodetestbucket/converted_data/attribution_data/server_datetime=2018-05-09/ecb5306fc9f3434985beaea0a1926ba9.snappy.parquet',
#   's3://dfncodetestbucket/converted_data/attribution_data/server_datetime=2018-05-10/ecb5306fc9f3434985beaea0a1926ba9.snappy.parquet',
#   's3://dfncodetestbucket/converted_data/attribution_data/server_datetime=2018-05-11/ecb5306fc9f3434985beaea0a1926ba9.snappy.parquet',
#   's3://dfncodetestbucket/converted_data/attribution_data/server_datetime=2018-05-12/ecb5306fc9f3434985beaea0a1926ba9.snappy.parquet',
#   's3://dfncodetestbucket/converted_data/attribution_data/server_datetime=2018-05-13/ecb5306fc9f3434985beaea0a1926ba9.snappy.parquet',
#   's3://dfncodetestbucket/converted_data/attribution_data/server_datetime=2018-05-14/ecb5306fc9f3434985beaea0a1926ba9.snappy.parquet',
#   's3://dfncodetestbucket/converted_data/attribution_data/server_datetime=2018-05-15/ecb5306fc9f3434985beaea0a1926ba9.snappy.parquet',
#   's3://dfncodetestbucket/converted_data/attribution_data/server_datetime=2018-05-16/ecb5306fc9f3434985beaea0a1926ba9.snappy.parquet',
#   's3://dfncodetestbucket/converted_data/attribution_data/server_datetime=2018-05-17/ecb5306fc9f3434985beaea0a1926ba9.snappy.parquet',
#   's3://dfncodetestbucket/converted_data/attribution_data/server_datetime=2018-05-18/ecb5306fc9f3434985beaea0a1926ba9.snappy.parquet',
#   's3://dfncodetestbucket/converted_data/attribution_data/server_datetime=2018-05-19/ecb5306fc9f3434985beaea0a1926ba9.snappy.parquet',
#   's3://dfncodetestbucket/converted_data/attribution_data/server_datetime=2018-05-20/ecb5306fc9f3434985beaea0a1926ba9.snappy.parquet',
#   's3://dfncodetestbucket/converted_data/attribution_data/server_datetime=2018-05-21/ecb5306fc9f3434985beaea0a1926ba9.snappy.parquet',
#   's3://dfncodetestbucket/converted_data/attribution_data/server_datetime=2018-05-22/ecb5306fc9f3434985beaea0a1926ba9.snappy.parquet',
#   's3://dfncodetestbucket/converted_data/attribution_data/server_datetime=2018-05-23/ecb5306fc9f3434985beaea0a1926ba9.snappy.parquet',
#   's3://dfncodetestbucket/converted_data/attribution_data/server_datetime=2018-05-24/ecb5306fc9f3434985beaea0a1926ba9.snappy.parquet',
#   's3://dfncodetestbucket/converted_data/attribution_data/server_datetime=2018-05-25/ecb5306fc9f3434985beaea0a1926ba9.snappy.parquet',
#   's3://dfncodetestbucket/converted_data/attribution_data/server_datetime=2018-05-26/ecb5306fc9f3434985beaea0a1926ba9.snappy.parquet',
#   's3://dfncodetestbucket/converted_data/attribution_data/server_datetime=2018-05-27/ecb5306fc9f3434985beaea0a1926ba9.snappy.parquet',
#   's3://dfncodetestbucket/converted_data/attribution_data/server_datetime=2018-05-28/ecb5306fc9f3434985beaea0a1926ba9.snappy.parquet',
#   's3://dfncodetestbucket/converted_data/attribution_data/server_datetime=2018-05-29/ecb5306fc9f3434985beaea0a1926ba9.snappy.parquet',
#   's3://dfncodetestbucket/converted_data/attribution_data/server_datetime=2018-05-30/ecb5306fc9f3434985beaea0a1926ba9.snappy.parquet',
#   's3://dfncodetestbucket/converted_data/attribution_data/server_datetime=2018-05-31/ecb5306fc9f3434985beaea0a1926ba9.snappy.parquet',
#   's3://dfncodetestbucket/converted_data/attribution_data/server_datetime=2018-06-01/ecb5306fc9f3434985beaea0a1926ba9.snappy.parquet',
#   's3://dfncodetestbucket/converted_data/attribution_data/server_datetime=2018-06-02/ecb5306fc9f3434985beaea0a1926ba9.snappy.parquet',
#   's3://dfncodetestbucket/converted_data/attribution_data/server_datetime=2018-06-03/ecb5306fc9f3434985beaea0a1926ba9.snappy.parquet',
#   's3://dfncodetestbucket/converted_data/attribution_data/server_datetime=2018-06-04/ecb5306fc9f3434985beaea0a1926ba9.snappy.parquet',
#   's3://dfncodetestbucket/converted_data/attribution_data/server_datetime=2018-06-05/ecb5306fc9f3434985beaea0a1926ba9.snappy.parquet',
#   's3://dfncodetestbucket/converted_data/attribution_data/server_datetime=2018-06-06/ecb5306fc9f3434985beaea0a1926ba9.snappy.parquet',
#   's3://dfncodetestbucket/converted_data/attribution_data/server_datetime=2018-06-07/ecb5306fc9f3434985beaea0a1926ba9.snappy.parquet',
#   's3://dfncodetestbucket/converted_data/attribution_data/server_datetime=2018-06-08/ecb5306fc9f3434985beaea0a1926ba9.snappy.parquet',
#   's3://dfncodetestbucket/converted_data/attribution_data/server_datetime=2018-06-09/ecb5306fc9f3434985beaea0a1926ba9.snappy.parquet',
#   's3://dfncodetestbucket/converted_data/attribution_data/server_datetime=2018-06-10/ecb5306fc9f3434985beaea0a1926ba9.snappy.parquet',
#   's3://dfncodetestbucket/converted_data/attribution_data/server_datetime=2018-06-11/ecb5306fc9f3434985beaea0a1926ba9.snappy.parquet',
#   's3://dfncodetestbucket/converted_data/attribution_data/server_datetime=2018-06-12/ecb5306fc9f3434985beaea0a1926ba9.snappy.parquet',
#   's3://dfncodetestbucket/converted_data/attribution_data/server_datetime=2018-06-13/ecb5306fc9f3434985beaea0a1926ba9.snappy.parquet'],
#  'partitions_values': {'s3://dfncodetestbucket/converted_data/attribution_data/server_datetime=2018-05-02/': ['2018-05-02'],
#   's3://dfncodetestbucket/converted_data/attribution_data/server_datetime=2018-05-03/': ['2018-05-03'],
#   's3://dfncodetestbucket/converted_data/attribution_data/server_datetime=2018-05-04/': ['2018-05-04'],
#   's3://dfncodetestbucket/converted_data/attribution_data/server_datetime=2018-05-05/': ['2018-05-05'],
#   's3://dfncodetestbucket/converted_data/attribution_data/server_datetime=2018-05-06/': ['2018-05-06'],
#   's3://dfncodetestbucket/converted_data/attribution_data/server_datetime=2018-05-07/': ['2018-05-07'],
#   's3://dfncodetestbucket/converted_data/attribution_data/server_datetime=2018-05-08/': ['2018-05-08'],
#   's3://dfncodetestbucket/converted_data/attribution_data/server_datetime=2018-05-09/': ['2018-05-09'],
#   's3://dfncodetestbucket/converted_data/attribution_data/server_datetime=2018-05-10/': ['2018-05-10'],
#   's3://dfncodetestbucket/converted_data/attribution_data/server_datetime=2018-05-11/': ['2018-05-11'],
#   's3://dfncodetestbucket/converted_data/attribution_data/server_datetime=2018-05-12/': ['2018-05-12'],
#   's3://dfncodetestbucket/converted_data/attribution_data/server_datetime=2018-05-13/': ['2018-05-13'],
#   's3://dfncodetestbucket/converted_data/attribution_data/server_datetime=2018-05-14/': ['2018-05-14'],
#   's3://dfncodetestbucket/converted_data/attribution_data/server_datetime=2018-05-15/': ['2018-05-15'],
#   's3://dfncodetestbucket/converted_data/attribution_data/server_datetime=2018-05-16/': ['2018-05-16'],
#   's3://dfncodetestbucket/converted_data/attribution_data/server_datetime=2018-05-17/': ['2018-05-17'],
#   's3://dfncodetestbucket/converted_data/attribution_data/server_datetime=2018-05-18/': ['2018-05-18'],
#   's3://dfncodetestbucket/converted_data/attribution_data/server_datetime=2018-05-19/': ['2018-05-19'],
#   's3://dfncodetestbucket/converted_data/attribution_data/server_datetime=2018-05-20/': ['2018-05-20'],
#   's3://dfncodetestbucket/converted_data/attribution_data/server_datetime=2018-05-21/': ['2018-05-21'],
#   's3://dfncodetestbucket/converted_data/attribution_data/server_datetime=2018-05-22/': ['2018-05-22'],
#   's3://dfncodetestbucket/converted_data/attribution_data/server_datetime=2018-05-23/': ['2018-05-23'],
#   's3://dfncodetestbucket/converted_data/attribution_data/server_datetime=2018-05-24/': ['2018-05-24'],
#   's3://dfncodetestbucket/converted_data/attribution_data/server_datetime=2018-05-25/': ['2018-05-25'],
#   's3://dfncodetestbucket/converted_data/attribution_data/server_datetime=2018-05-26/': ['2018-05-26'],
#   's3://dfncodetestbucket/converted_data/attribution_data/server_datetime=2018-05-27/': ['2018-05-27'],
#   's3://dfncodetestbucket/converted_data/attribution_data/server_datetime=2018-05-28/': ['2018-05-28'],
#   's3://dfncodetestbucket/converted_data/attribution_data/server_datetime=2018-05-29/': ['2018-05-29'],
#   's3://dfncodetestbucket/converted_data/attribution_data/server_datetime=2018-05-30/': ['2018-05-30'],
#   's3://dfncodetestbucket/converted_data/attribution_data/server_datetime=2018-05-31/': ['2018-05-31'],
#   's3://dfncodetestbucket/converted_data/attribution_data/server_datetime=2018-06-01/': ['2018-06-01'],
#   's3://dfncodetestbucket/converted_data/attribution_data/server_datetime=2018-06-02/': ['2018-06-02'],
#   's3://dfncodetestbucket/converted_data/attribution_data/server_datetime=2018-06-03/': ['2018-06-03'],
#   's3://dfncodetestbucket/converted_data/attribution_data/server_datetime=2018-06-04/': ['2018-06-04'],
#   's3://dfncodetestbucket/converted_data/attribution_data/server_datetime=2018-06-05/': ['2018-06-05'],
#   's3://dfncodetestbucket/converted_data/attribution_data/server_datetime=2018-06-06/': ['2018-06-06'],
#   's3://dfncodetestbucket/converted_data/attribution_data/server_datetime=2018-06-07/': ['2018-06-07'],
#   's3://dfncodetestbucket/converted_data/attribution_data/server_datetime=2018-06-08/': ['2018-06-08'],
#   's3://dfncodetestbucket/converted_data/attribution_data/server_datetime=2018-06-09/': ['2018-06-09'],
#   's3://dfncodetestbucket/converted_data/attribution_data/server_datetime=2018-06-10/': ['2018-06-10'],
#   's3://dfncodetestbucket/converted_data/attribution_data/server_datetime=2018-06-11/': ['2018-06-11'],
#   's3://dfncodetestbucket/converted_data/attribution_data/server_datetime=2018-06-12/': ['2018-06-12'],
#   's3://dfncodetestbucket/converted_data/attribution_data/server_datetime=2018-06-13/': ['2018-06-13']}}

# %%
wr.catalog.create_parquet_table(
    database = "dfncodetestdb",
    table = "attribution_data_table",
    path=standardized_path,
    columns_types = {"partner" : "string", 
                    "campaign" : "string",
                    "tracker_id" : "string",
                    "log_id" : "string",
                    "attribution_type" : "int",
                    "identity_adid" : "string"
                    },
    partitions_types = {'server_datetime' : "string"},
    compression = 'snappy',
    description = "test",
    columns_comments = {"partner" : "partner name", 
                        "campaign" : "campaign name",
                        'server_datetime' : "server datetime",
                        "tracker_id" : "tracker ids",
                        "log_id" : "log ids",
                        "attribution_type" : "types of attribution",
                        "identity_adid" : "id"
                        })

# %%
wr.athena.repair_table(database = "dfncodetestdb",
                       table = "attribution_data_table",
                       s3_output = standardized_path)
# Out:
# 'SUCCEEDED'

# %%
raw_s3_bucket = "dfncodetestbucket"
raw_path_dir = "original_data/event_data"
raw_path = f"s3://{raw_s3_bucket}/{raw_path_dir}"

standardized_s3_bucket = "dfncodetestbucket" 
standard_path_dir = "converted_data/event_data/"
standardized_path = f"s3://{standardized_s3_bucket}/{standard_path_dir}"

# %%
header = ['identity_adid', 'os', 'model', 'country', 'event_name', 'log_id', 'server_datetime', 'quantity', 'price']

df = wr.s3.read_csv(raw_path, names=header)
df.head()
# Out:
#    identity_adid   os  model country         event_name  \
# 0      984549936  8.9    8.9      jp          abx:login
# 1      885033552  8.9    8.9      gb          abx:login
# 2      768602461  7.1    7.1      ge      abx:firstopen
# 3     1666798466  3.4    3.4      gb    abx:end_session
# 4      683694696  7.1    7.1      kr  abx:start_session
#
#                                  log_id          server_datetime  quantity  \
# 0  c21efdb8-b6e5-4ccc-a474-aff72a62c248  2018-05-18 12:23:15.303       NaN
# 1  b4470f3b-4bb9-43ef-9248-25b503fa5660  2018-05-18 12:32:46.395       NaN
# 2  372dfecc-a27f-4a16-8e31-eccf34b8855f  2018-05-18 12:34:55.196       NaN
# 3  08730bdc-2895-4061-8399-f45df94d3fd0  2018-05-18 12:30:23.945       NaN
# 4  a9556df7-f6ee-4600-af5b-89a44f18673c  2018-05-18 12:31:14.824       NaN
#
#    price
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN

# %%
df = df.astype({"identity_adid" : "str", 
                "os" : "str",
                "model" : "str",
                "country" : "str",
                "event_name" : "str",
                "quantity" : "Int64",
                "price" : "float"
                })

# %%
df["server_datetime"] = pd.to_datetime(df["server_datetime"], errors = 'coerce')

# %%
df['server_datetime'] = df["server_datetime"].dt.strftime("%Y-%m-%d")

# %%
df.head()
# Out:
#   identity_adid   os model country         event_name  \
# 0     984549936  8.9   8.9      jp          abx:login
# 1     885033552  8.9   8.9      gb          abx:login
# 2     768602461  7.1   7.1      ge      abx:firstopen
# 3    1666798466  3.4   3.4      gb    abx:end_session
# 4     683694696  7.1   7.1      kr  abx:start_session
#
#                                  log_id server_datetime  quantity  price
# 0  c21efdb8-b6e5-4ccc-a474-aff72a62c248      2018-05-18      <NA>    NaN
# 1  b4470f3b-4bb9-43ef-9248-25b503fa5660      2018-05-18      <NA>    NaN
# 2  372dfecc-a27f-4a16-8e31-eccf34b8855f      2018-05-18      <NA>    NaN
# 3  08730bdc-2895-4061-8399-f45df94d3fd0      2018-05-18      <NA>    NaN
# 4  a9556df7-f6ee-4600-af5b-89a44f18673c      2018-05-18      <NA>    NaN

# %%
df.dtypes
# Out:
# identity_adid       object
# os                  object
# model               object
# country             object
# event_name          object
# log_id              object
# server_datetime     object
# quantity             Int64
# price              float64
# dtype: object

# %%
partition = ['server_datetime']
wr.s3.to_parquet(df, path=standardized_path, dataset=True, partition_cols=partition)
# Out:
# {'paths': ['s3://dfncodetestbucket/converted_data/event_data/server_datetime=2018-05-01/701e4b51fe7d48059b5292cb79d66eef.snappy.parquet',
#   's3://dfncodetestbucket/converted_data/event_data/server_datetime=2018-05-02/701e4b51fe7d48059b5292cb79d66eef.snappy.parquet',
#   's3://dfncodetestbucket/converted_data/event_data/server_datetime=2018-05-03/701e4b51fe7d48059b5292cb79d66eef.snappy.parquet',
#   's3://dfncodetestbucket/converted_data/event_data/server_datetime=2018-05-04/701e4b51fe7d48059b5292cb79d66eef.snappy.parquet',
#   's3://dfncodetestbucket/converted_data/event_data/server_datetime=2018-05-05/701e4b51fe7d48059b5292cb79d66eef.snappy.parquet',
#   's3://dfncodetestbucket/converted_data/event_data/server_datetime=2018-05-06/701e4b51fe7d48059b5292cb79d66eef.snappy.parquet',
#   's3://dfncodetestbucket/converted_data/event_data/server_datetime=2018-05-07/701e4b51fe7d48059b5292cb79d66eef.snappy.parquet',
#   's3://dfncodetestbucket/converted_data/event_data/server_datetime=2018-05-08/701e4b51fe7d48059b5292cb79d66eef.snappy.parquet',
#   's3://dfncodetestbucket/converted_data/event_data/server_datetime=2018-05-09/701e4b51fe7d48059b5292cb79d66eef.snappy.parquet',
#   's3://dfncodetestbucket/converted_data/event_data/server_datetime=2018-05-10/701e4b51fe7d48059b5292cb79d66eef.snappy.parquet',
#   's3://dfncodetestbucket/converted_data/event_data/server_datetime=2018-05-11/701e4b51fe7d48059b5292cb79d66eef.snappy.parquet',
#   's3://dfncodetestbucket/converted_data/event_data/server_datetime=2018-05-12/701e4b51fe7d48059b5292cb79d66eef.snappy.parquet',
#   's3://dfncodetestbucket/converted_data/event_data/server_datetime=2018-05-13/701e4b51fe7d48059b5292cb79d66eef.snappy.parquet',
#   's3://dfncodetestbucket/converted_data/event_data/server_datetime=2018-05-14/701e4b51fe7d48059b5292cb79d66eef.snappy.parquet',
#   's3://dfncodetestbucket/converted_data/event_data/server_datetime=2018-05-15/701e4b51fe7d48059b5292cb79d66eef.snappy.parquet',
#   's3://dfncodetestbucket/converted_data/event_data/server_datetime=2018-05-16/701e4b51fe7d48059b5292cb79d66eef.snappy.parquet',
#   's3://dfncodetestbucket/converted_data/event_data/server_datetime=2018-05-17/701e4b51fe7d48059b5292cb79d66eef.snappy.parquet',
#   's3://dfncodetestbucket/converted_data/event_data/server_datetime=2018-05-18/701e4b51fe7d48059b5292cb79d66eef.snappy.parquet',
#   's3://dfncodetestbucket/converted_data/event_data/server_datetime=2018-05-20/701e4b51fe7d48059b5292cb79d66eef.snappy.parquet',
#   's3://dfncodetestbucket/converted_data/event_data/server_datetime=2018-05-21/701e4b51fe7d48059b5292cb79d66eef.snappy.parquet',
#   's3://dfncodetestbucket/converted_data/event_data/server_datetime=2018-05-22/701e4b51fe7d48059b5292cb79d66eef.snappy.parquet',
#   's3://dfncodetestbucket/converted_data/event_data/server_datetime=2018-05-23/701e4b51fe7d48059b5292cb79d66eef.snappy.parquet',
#   's3://dfncodetestbucket/converted_data/event_data/server_datetime=2018-05-24/701e4b51fe7d48059b5292cb79d66eef.snappy.parquet',
#   's3://dfncodetestbucket/converted_data/event_data/server_datetime=2018-05-25/701e4b51fe7d48059b5292cb79d66eef.snappy.parquet',
#   's3://dfncodetestbucket/converted_data/event_data/server_datetime=2018-05-26/701e4b51fe7d48059b5292cb79d66eef.snappy.parquet',
#   's3://dfncodetestbucket/converted_data/event_data/server_datetime=2018-05-27/701e4b51fe7d48059b5292cb79d66eef.snappy.parquet',
#   's3://dfncodetestbucket/converted_data/event_data/server_datetime=2018-05-28/701e4b51fe7d48059b5292cb79d66eef.snappy.parquet',
#   's3://dfncodetestbucket/converted_data/event_data/server_datetime=2018-05-29/701e4b51fe7d48059b5292cb79d66eef.snappy.parquet',
#   's3://dfncodetestbucket/converted_data/event_data/server_datetime=2018-05-30/701e4b51fe7d48059b5292cb79d66eef.snappy.parquet',
#   's3://dfncodetestbucket/converted_data/event_data/server_datetime=2018-05-31/701e4b51fe7d48059b5292cb79d66eef.snappy.parquet',
#   's3://dfncodetestbucket/converted_data/event_data/server_datetime=2018-06-01/701e4b51fe7d48059b5292cb79d66eef.snappy.parquet',
#   's3://dfncodetestbucket/converted_data/event_data/server_datetime=2018-06-02/701e4b51fe7d48059b5292cb79d66eef.snappy.parquet',
#   's3://dfncodetestbucket/converted_data/event_data/server_datetime=2018-06-03/701e4b51fe7d48059b5292cb79d66eef.snappy.parquet',
#   's3://dfncodetestbucket/converted_data/event_data/server_datetime=2018-06-04/701e4b51fe7d48059b5292cb79d66eef.snappy.parquet',
#   's3://dfncodetestbucket/converted_data/event_data/server_datetime=2018-06-05/701e4b51fe7d48059b5292cb79d66eef.snappy.parquet',
#   's3://dfncodetestbucket/converted_data/event_data/server_datetime=2018-06-06/701e4b51fe7d48059b5292cb79d66eef.snappy.parquet',
#   's3://dfncodetestbucket/converted_data/event_data/server_datetime=2018-06-07/701e4b51fe7d48059b5292cb79d66eef.snappy.parquet',
#   's3://dfncodetestbucket/converted_data/event_data/server_datetime=2018-06-08/701e4b51fe7d48059b5292cb79d66eef.snappy.parquet',
#   's3://dfncodetestbucket/converted_data/event_data/server_datetime=2018-06-09/701e4b51fe7d48059b5292cb79d66eef.snappy.parquet',
#   's3://dfncodetestbucket/converted_data/event_data/server_datetime=2018-06-10/701e4b51fe7d48059b5292cb79d66eef.snappy.parquet',
#   's3://dfncodetestbucket/converted_data/event_data/server_datetime=2018-06-11/701e4b51fe7d48059b5292cb79d66eef.snappy.parquet',
#   's3://dfncodetestbucket/converted_data/event_data/server_datetime=2018-06-12/701e4b51fe7d48059b5292cb79d66eef.snappy.parquet',
#   's3://dfncodetestbucket/converted_data/event_data/server_datetime=2018-06-13/701e4b51fe7d48059b5292cb79d66eef.snappy.parquet'],
#  'partitions_values': {'s3://dfncodetestbucket/converted_data/event_data/server_datetime=2018-05-01/': ['2018-05-01'],
#   's3://dfncodetestbucket/converted_data/event_data/server_datetime=2018-05-02/': ['2018-05-02'],
#   's3://dfncodetestbucket/converted_data/event_data/server_datetime=2018-05-03/': ['2018-05-03'],
#   's3://dfncodetestbucket/converted_data/event_data/server_datetime=2018-05-04/': ['2018-05-04'],
#   's3://dfncodetestbucket/converted_data/event_data/server_datetime=2018-05-05/': ['2018-05-05'],
#   's3://dfncodetestbucket/converted_data/event_data/server_datetime=2018-05-06/': ['2018-05-06'],
#   's3://dfncodetestbucket/converted_data/event_data/server_datetime=2018-05-07/': ['2018-05-07'],
#   's3://dfncodetestbucket/converted_data/event_data/server_datetime=2018-05-08/': ['2018-05-08'],
#   's3://dfncodetestbucket/converted_data/event_data/server_datetime=2018-05-09/': ['2018-05-09'],
#   's3://dfncodetestbucket/converted_data/event_data/server_datetime=2018-05-10/': ['2018-05-10'],
#   's3://dfncodetestbucket/converted_data/event_data/server_datetime=2018-05-11/': ['2018-05-11'],
#   's3://dfncodetestbucket/converted_data/event_data/server_datetime=2018-05-12/': ['2018-05-12'],
#   's3://dfncodetestbucket/converted_data/event_data/server_datetime=2018-05-13/': ['2018-05-13'],
#   's3://dfncodetestbucket/converted_data/event_data/server_datetime=2018-05-14/': ['2018-05-14'],
#   's3://dfncodetestbucket/converted_data/event_data/server_datetime=2018-05-15/': ['2018-05-15'],
#   's3://dfncodetestbucket/converted_data/event_data/server_datetime=2018-05-16/': ['2018-05-16'],
#   's3://dfncodetestbucket/converted_data/event_data/server_datetime=2018-05-17/': ['2018-05-17'],
#   's3://dfncodetestbucket/converted_data/event_data/server_datetime=2018-05-18/': ['2018-05-18'],
#   's3://dfncodetestbucket/converted_data/event_data/server_datetime=2018-05-20/': ['2018-05-20'],
#   's3://dfncodetestbucket/converted_data/event_data/server_datetime=2018-05-21/': ['2018-05-21'],
#   's3://dfncodetestbucket/converted_data/event_data/server_datetime=2018-05-22/': ['2018-05-22'],
#   's3://dfncodetestbucket/converted_data/event_data/server_datetime=2018-05-23/': ['2018-05-23'],
#   's3://dfncodetestbucket/converted_data/event_data/server_datetime=2018-05-24/': ['2018-05-24'],
#   's3://dfncodetestbucket/converted_data/event_data/server_datetime=2018-05-25/': ['2018-05-25'],
#   's3://dfncodetestbucket/converted_data/event_data/server_datetime=2018-05-26/': ['2018-05-26'],
#   's3://dfncodetestbucket/converted_data/event_data/server_datetime=2018-05-27/': ['2018-05-27'],
#   's3://dfncodetestbucket/converted_data/event_data/server_datetime=2018-05-28/': ['2018-05-28'],
#   's3://dfncodetestbucket/converted_data/event_data/server_datetime=2018-05-29/': ['2018-05-29'],
#   's3://dfncodetestbucket/converted_data/event_data/server_datetime=2018-05-30/': ['2018-05-30'],
#   's3://dfncodetestbucket/converted_data/event_data/server_datetime=2018-05-31/': ['2018-05-31'],
#   's3://dfncodetestbucket/converted_data/event_data/server_datetime=2018-06-01/': ['2018-06-01'],
#   's3://dfncodetestbucket/converted_data/event_data/server_datetime=2018-06-02/': ['2018-06-02'],
#   's3://dfncodetestbucket/converted_data/event_data/server_datetime=2018-06-03/': ['2018-06-03'],
#   's3://dfncodetestbucket/converted_data/event_data/server_datetime=2018-06-04/': ['2018-06-04'],
#   's3://dfncodetestbucket/converted_data/event_data/server_datetime=2018-06-05/': ['2018-06-05'],
#   's3://dfncodetestbucket/converted_data/event_data/server_datetime=2018-06-06/': ['2018-06-06'],
#   's3://dfncodetestbucket/converted_data/event_data/server_datetime=2018-06-07/': ['2018-06-07'],
#   's3://dfncodetestbucket/converted_data/event_data/server_datetime=2018-06-08/': ['2018-06-08'],
#   's3://dfncodetestbucket/converted_data/event_data/server_datetime=2018-06-09/': ['2018-06-09'],
#   's3://dfncodetestbucket/converted_data/event_data/server_datetime=2018-06-10/': ['2018-06-10'],
#   's3://dfncodetestbucket/converted_data/event_data/server_datetime=2018-06-11/': ['2018-06-11'],
#   's3://dfncodetestbucket/converted_data/event_data/server_datetime=2018-06-12/': ['2018-06-12'],
#   's3://dfncodetestbucket/converted_data/event_data/server_datetime=2018-06-13/': ['2018-06-13']}}

# %%
wr.catalog.create_parquet_table(
    database = "dfncodetestdb",
    table = "event_data_table",
    path=standardized_path,
    columns_types = {"identity_adid" : "string",
                     "os" : "string", 
                    "model" : "string",
                    "country" : "string",
                    "event_name" : "string",
                    "quantity" : "int",
                    "price" : "double"
                    },
    partitions_types = {'server_datetime' : "string"},
    compression = 'snappy',
    description = "test",
    columns_comments = {"identity_adid" :
                        "id",
                         "os" : "os type", 
                        "model" : "model type",
                        "country" : "name of country",
                        "event_name" : "event name",
                        "quantity" : "counts of purchase",
                        "price" : "amount of purchase"
                        })

# %%
wr.athena.repair_table(database = "dfncodetestdb",
                       table = "event_data_table",
                       s3_output = standardized_path)
# Out:
# 'SUCCEEDED'
